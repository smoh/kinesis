# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import astropy.units as u
import astropy.coordinates as coord
from astropy.table import Table

import gapipes as gp
import kinesis as kn

# %%
df = kn.data.load_hyades_dataset()

# %%
df.columns[df.columns.str.contains('r19')]
# Out:
# Index(['Member_r19', 'Comment_r19'], dtype='object')

# %%
df['Member_r19'].value_counts()
# Out:
# Cluster    501
# Pr_tail    292
# other      286
# Tr_tail    237
# Name: Member_r19, dtype: int64

# %%
for l, g in df.groupby(df['Member_r19']):
    plt.plot(g['gx'],g['gy'],'.',label=l)
plt.legend()

# %%
other = df.groupby(df['Member_r19']).get_group('other')
cl = df.groupby(df['Member_r19']).get_group('cl')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-356983af62c0> in <module>
#       1 other = df.groupby(df['Member_r19']).get_group('other')
# ----> 2 cl = df.groupby(df['Member_r19']).get_group('cl')
#
# ~/.conda/envs/nitro/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     678         inds = self._get_index(name)
#     679         if not len(inds):
# --> 680             raise KeyError(name)
#     681
#     682         return obj.take(inds, axis=self.axis)
#
# KeyError: 'cl'

# %%
df_noother = df.loc[df['Member_r19']!='other']
plt.plot(df_noother['gz'],df_noother['gvz'],'.')

plt.ylim(-5,5)
# Out:
# (-5, 5)

# %%
plt.plot(df_noother['gx'],df_noother['gvx'],'.')
